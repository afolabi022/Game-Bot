# %%
# import pandas as pd 
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

music_data=pd.read_csv("music.csv")
X=music_data.drop(columns=["genre"])
Y= music_data['genre']
X_train, X_test,Y_train, Y_test = train_test_split(X,Y, test_size=0.2)

model = DecisionTreeClassifier()
model.fit(X_train,Y_train)
predictions = model.predict([  [21, 1], [22, 0]])
import warnings 
warnings.filterwarnings("ignore")
predictions= model.predict(X_test)

score = accuracy_score(Y_test,predictions)
score
# Out:
# 0.75

# %%
import pandas as pd 
from sklearn.tree import DecisionTreeClassifier
import joblib

music_data = pd.read_csv("colors.csv")
X=music_data.drop(columns=["genre"])
Y= music_data['genre']

model = DecisionTreeClassifier()
model.fit(X, Y)

model = joblib.dump(model,  "music-recommender.joblib")
predictions = model.predict([[21, 1]])
predictions
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 5
#       2 from sklearn.tree import DecisionTreeClassifier
#       3 import joblib
# ----> 5 music_data = pd.read_csv("colors.csv")
#       6 X=music_data.drop(columns=["genre"])
#       7 Y= music_data['genre']
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
import pandas as pd 
import numpy as np
import plotly. express as px
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("colours.csv")

# %%
df
# Out:
#                             Name       Hex    Red Green  Blue    Hue  \
# 0                  Absolute Zero  #0048BA     0%   28%   73%   217°
# 1                     Acid green  #B0BF1A    69%   75%   10%    65°
# 2                           Aero  #7CB9E8    49%   73%   91%   206°
# 3                 African violet  #B284BE    70%   52%   75%   288°
# 4           Air superiority blue  #72A0C1    45%   63%   76%   205°
# ..                           ...       ...    ...   ...   ...    ...
# 817                Yellow Orange  #FFAE42   100%   68%   26%    34°
# 818  Yellow Orange (Color Wheel)  #FF9505   100%   58%    2%    36°
# 819                   YInMn Blue  #2E5090    18%   31%   56%   219°
# 820                       Zaffre  #0014A8     0%    8%   66%   233°
# 821                         Zomp  #39A78E    22%   65%   56%   166°
#
#     SaturationHSL LightHSL SaturationHSV LightHSV
# 0           100%      37%          100%       73%
# ...

# %%
df.shape
# Out:
# (822, 10)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                             Name       Hex    Red Green  Blue    Hue  \
# 0                  Absolute Zero  #0048BA     0%   28%   73%   217°
# 1                     Acid green  #B0BF1A    69%   75%   10%    65°
# 2                           Aero  #7CB9E8    49%   73%   91%   206°
# 3                 African violet  #B284BE    70%   52%   75%   288°
# 4           Air superiority blue  #72A0C1    45%   63%   76%   205°
# ..                           ...       ...    ...   ...   ...    ...
# 817                Yellow Orange  #FFAE42   100%   68%   26%    34°
# 818  Yellow Orange (Color Wheel)  #FF9505   100%   58%    2%    36°
# 819                   YInMn Blue  #2E5090    18%   31%   56%   219°
# 820                       Zaffre  #0014A8     0%    8%   66%   233°
# 821                         Zomp  #39A78E    22%   65%   56%   166°
#
#     SaturationHSL LightHSL SaturationHSV LightHSV
# 0           100%      37%          100%       73%
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Hex', 'Red', 'Green', 'Blue', 'Hue', 'SaturationHSL',
#        'LightHSL', 'SaturationHSV', 'LightHSV'],
#       dtype='object')

# %%
df.columns=df1=Index(['Name', , 'Red', 'Green', 'Blue'],
# Out:
#   Cell In[15], line 1
#     df.columns=df1=Index(['Name', , 'Red', 'Green', 'Blue'],
#                                   ^
# SyntaxError: invalid syntax

# %%
import pandas as pd 
import numpy as np

# %%
video_games = pd.read_csv("vgsales.csv")

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
# ...

# %%
df.isnull()
# Out:
#         Rank   Name  Platform   Year  Genre  Publisher  NA_Sales  EU_Sales  \
# 0      False  False     False  False  False      False     False     False
# 1      False  False     False  False  False      False     False     False
# 2      False  False     False  False  False      False     False     False
# 3      False  False     False  False  False      False     False     False
# 4      False  False     False  False  False      False     False     False
# ...      ...    ...       ...    ...    ...        ...       ...       ...
# 16593  False  False     False  False  False      False     False     False
# 16594  False  False     False  False  False      False     False     False
# 16595  False  False     False  False  False      False     False     False
# 16596  False  False     False  False  False      False     False     False
# 16597  False  False     False  False  False      False     False     False
#
#        JP_Sales  Other_Sales  Global_Sales
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
video_games_subset = video_games['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'Global_Sales'}]
# Out:
#   Cell In[36], line 1
#     video_games_subset=video_games['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'Global_Sales'}]
#                                                                                                            ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '['

# %%
video_games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df=df.drop(['NA_Sales','EU_Sales','JP_Sales', 'Other_Sales'], axis = 1)

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  Global_Sales
# ...

# %%
video_games = df

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  Global_Sales
# ...

# %%
video_games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  Global_Sales
# ...

# %%
video_games.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# Global_Sales      0
# dtype: int64

# %%
video_games.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# Global_Sales    float64
# dtype: object

# %%
video_games[video_games['Year'].isnull()]
# Out:
#         Rank                         Name Platform  Year         Genre  \
# 179      180              Madden NFL 2004      PS2   NaN        Sports
# 377      378             FIFA Soccer 2004      PS2   NaN        Sports
# 431      432   LEGO Batman: The Videogame      Wii   NaN        Action
# 470      471   wwe Smackdown vs. Raw 2006      PS2   NaN      Fighting
# 607      608               Space Invaders     2600   NaN       Shooter
# ...      ...                          ...      ...   ...           ...
# 16307  16310                Freaky Flyers       GC   NaN        Racing
# 16327  16330                    Inversion       PC   NaN       Shooter
# 16366  16369  Hakuouki: Shinsengumi Kitan      PS3   NaN     Adventure
# 16427  16430                 Virtua Quest       GC   NaN  Role-Playing
# 16493  16496                   The Smurfs      3DS   NaN        Action
#
#                                     Publisher  Global_Sales
# ...

# %%
video_games['Year'].fillna('2006',inplace = True)

# %%
video_games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  Global_Sales
# ...

# %%
video_games.isnull().sum()
# Out:
# Rank             0
# Name             0
# Platform         0
# Year             0
# Genre            0
# Publisher       58
# Global_Sales     0
# dtype: int64

# %%
video_games['Publisher'].fillna('Electronic Arts',inplace = True )

# %%
video_games.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# Global_Sales    0
# dtype: int64

# %%
video_games[video_games['Year'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, Global_Sales]
# Index: []

# %%
video_games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  Global_Sales
# ...

# %%
video_games.hist(bins=60)
# Out:
# array([[<Axes: title={'center': 'Rank'}>,
#         <Axes: title={'center': 'Global_Sales'}>]], dtype=object)

# %%
from matplotlib import pyplot as plt
pd.DataFrame(video_games['Year'].value_counts()).plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 from matplotlib import pyplot as plt
# ----> 2 pd.DataFrame(video_games['Year'].value_counts()).plot(kind='bar')
#
# NameError: name 'video_games' is not defined

# %%
import pandas as pd 
video_games=df
pd.DataFrame(video_games['Name'].value_counts()).plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pandas as pd
# ----> 2 video_games=df
#       3 pd.DataFrame(video_games['Name'].value_counts()).plot(kind='bar')
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv('vgsales.csv')

# %%
df= video_games
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df= video_games
#
# NameError: name 'video_games' is not defined

# %%
video_games=df

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.drop
# Out:
# <bound method DataFrame.drop of         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df = df.drop(['Rank','NA_Sales',
       'EU_Sales', 'JP_Sales', 'Other_Sales'],
      axis =1 )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df = df.drop(['Rank','NA_Sales',
#       2        'EU_Sales', 'JP_Sales', 'Other_Sales'],
#       3       axis =1 )
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
import pandas as pd 
import numpy as np
df=pd.read_csv('vehicles')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 df=pd.read_csv('vehicles')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df=pd.read_csv('vehicles')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df=pd.read_csv('vehicles')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd 
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import joblib
from sklearn import tree
import os
df = pd.read_csv("vgsales.csv")

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
video_games = df

# %%
video_games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
video_games=df.drop(['NA_Sales','EU_Sales','JP_Sales','Other_Sales'],axis=1,)

# %%
video_games.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
video_games.isnull()
# Out:
#         Rank   Name  Platform   Year  Genre  Publisher  Global_Sales
# 0      False  False     False  False  False      False         False
# 1      False  False     False  False  False      False         False
# 2      False  False     False  False  False      False         False
# 3      False  False     False  False  False      False         False
# 4      False  False     False  False  False      False         False
# ...      ...    ...       ...    ...    ...        ...           ...
# 16593  False  False     False  False  False      False         False
# 16594  False  False     False  False  False      False         False
# 16595  False  False     False  False  False      False         False
# 16596  False  False     False  False  False      False         False
# 16597  False  False     False  False  False      False         False
#
# [16598 rows x 7 columns]

# %%
video_games.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# Global_Sales      0
# dtype: int64

# %%
video_games['Year'].fillna('2006',inplace = True )

# %%
video_games['Publisher'].fillna('Electronic Arts',inplace = True)

# %%
video_games.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# Global_Sales    0
# dtype: int64

# %%
video_games.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year             object
# Genre            object
# Publisher        object
# Global_Sales    float64
# dtype: object

# %%
video_games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  Global_Sales
# ...

# %%
df['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
df['Genre'].value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Label_Encoder=LabelEncoder()

# %%
print(Label_Encoder)
# Out:
# LabelEncoder()

# %%
video_games['Genre'] = Label_Encoder.fit_transform(video_games['Genre'])

# %%
video_games.head()
# Out:
#    Rank                      Name Platform    Year  Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0     10  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      4  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0      6  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0     10  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0      7  Nintendo
#
#    Global_Sales
# 0         82.74
# 1         40.24
# 2         35.82
# 3         33.00
# 4         31.37

# %%
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre             int32
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
video_games.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year             object
# Genre            object
# Publisher        object
# Global_Sales    float64
# dtype: object

# %%
video_games['Publisher'] = Label_Encoder.fit_transform(video_games['Publisher'])

# %%
video_games.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year             object
# Genre             int32
# Publisher         int32
# Global_Sales    float64
# dtype: object

# %%
video_games['Publisher'].unique()
# Out:
# array([359, 323, 494, 456,  21, 525,  66, 138, 446, 466,  53,   6,  85,
#        177, 275, 458, 465, 288, 542, 549, 529, 137, 426, 545, 144, 347,
#        385, 214, 488, 164,  17, 292, 126, 296,  91, 424, 281,  40, 325,
#        253, 120,  10, 343, 522, 391, 308, 237, 500, 534,  13, 330, 241,
#        530, 463, 533,  23,  63, 109, 378, 425, 539, 219, 198, 199, 552,
#        206, 101, 224,  94, 430,  55, 486,  12, 567,  18, 460,   4, 419,
#        348, 160,  30,  71, 461, 303, 372, 566, 413,  88, 142, 473,  97,
#        434, 491,  27, 176, 322, 400, 451, 512, 441, 273, 182, 509, 299,
#        191, 334, 398,  84, 496, 104, 436, 414, 576, 420, 526, 443, 246,
#        341,  87, 464,   2,  58, 223, 367, 314, 365,  67, 514, 462, 256,
#        362, 277, 415, 233, 507, 170, 432, 318, 305, 227, 433, 457, 528,
#        193, 554,  61, 381, 516, 279, 232, 492, 263, 122, 146, 559, 238,
#        482,  83,  44, 186, 324, 255,  36, 555,  22, 383, 422, 558, 527,
# ...

# %%
video_games['Publisher'].value_counts()
# Out:
# 138    1409
# 21      975
# 347     932
# 525     921
# 275     832
#        ...
# 550       1
# 353       1
# 141       1
# 151       1
# 524       1
# Name: Publisher, Length: 578, dtype: int64

# %%
X=video_games.drop(['Global_Sales','Name','Platform','Year',"Rank"], axis = 1)

# %%
X
# Out:
#        Genre  Publisher
# 0         10        359
# 1          4        359
# 2          6        359
# 3         10        359
# 4          7        359
# ...      ...        ...
# 16593      4        269
# 16594      8        241
# 16595      6         21
# 16596      5          8
# 16597      4        546
#
# [16598 rows x 2 columns]

# %%
Y=video_games['Name']

# %%
Y
# Out:
# 0                                              Wii Sports
# 1                                       Super Mario Bros.
# 2                                          Mario Kart Wii
# 3                                       Wii Sports Resort
# 4                                Pokemon Red/Pokemon Blue
#                                ...
# 16593                  Woody Woodpecker in Crazy Castle 5
# 16594                       Men in Black II: Alien Escape
# 16595    SCORE International Baja 1000: The Official Game
# 16596                                          Know How 2
# 16597                                    Spirits & Spells
# Name: Name, Length: 16598, dtype: object

# %%
model = DecisionTreeClassifier()
model.fit(X,Y)
video_games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year  Genre  Publisher  Global_Sales
# 0      2006.0     10        359         82.74
# ...

# %%
model.fit(X,Y)
# Out:
# DecisionTreeClassifier()

# %%
video_games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year  Genre  Publisher  Global_Sales
# 0      2006.0     10        359         82.74
# ...

# %%
predictions
# Out:
# array(['Dance Party: Pop Hits', "Let's Play Garden", 'FIFA 14', ...,
#        'Daito Giken Koushiki Pachi-Slot Simulator: 24 - Twenty-Four',
#        'Homefront', 'Lego Batman 3: Beyond Gotham'], dtype=object)

# %%
#X=video_games.drop(['Global_Sales','Name','Platform','Year',"Rank"], axis = 1)
#Y=video_games['Name']
#X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25)
#model.fit(X_train, Y_train)
#predictions= model.predict(X_test)

joblib.dump(model, r"C:\\Users\\SurfaceBook\\Desktop\v-game.joblib")

#score =accuracy_score(Y_test, predictions)
#model= joblib.load('Video_Game-recommender.joblib')
#predictions= model.predict([[10,359]])
#predictions
# Out:
# ['C:\\\\Users\\\\SurfaceBook\\\\Desktop\\v-game.joblib']

# %%
X=video_games.drop(['Global_Sales','Name','Platform','Year',"Rank"], axis = 1)
Y=video_games['Name']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25)
model.fit(X_train, Y_train)

model= joblib.load('V-Game.joblib')
predictions= model.predict([[5,246]])
predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 X=video_games.drop(['Global_Sales','Name','Platform','Year',"Rank"], axis = 1)
#       2 Y=video_games['Name']
#       3 X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25)
#
# NameError: name 'video_games' is not defined

# %%
tree.export_graphviz(model,out_file="V-Game.dot",
                     feature_names=['Genre','Publisher'],
                     class_names= sorted(Y.unique()),
                        label= 'all',
                       rounded= True,
                        filled = True)

# %%
df
